# %% [markdown]
# ## Set

# %%
A={12,23,45,67,88,90}
A
# Out:
# {12, 23, 45, 67, 88, 90}

# %%
B={"neha","pooja","geeta"}
B
# Out:
# {'geeta', 'neha', 'pooja'}

# %% [markdown]
#  #### Intersection, Union, Difference

# %%
### Intersection
A={1,2,3,4,5}
B={6,4,5,6,8,9,7}
A.intersection(B)
# Out:
# {4, 5}

# %%
P={'lk','op','jk','ui'}
Q={'rt','fg','ui','op'}
P.intersection(Q)
# Out:
# {'op', 'ui'}

# %%
P={'lk','op','jk','ui'}
Q={'rt','fg','ui','op'}
Q.intersection(P)
# Out:
# {'op', 'ui'}

# %%
S={12.9,12.8,12.7,12.6,11.5}
R={12.8,11,12.2,13.6,11.6}
S.intersection(R)
# Out:
# {12.8}

# %%
### Union
A={1,2,3,4,8,7}
B={1,2,8,9,10,11}
A.union(B)
# Out:
# {1, 2, 3, 4, 7, 8, 9, 10, 11}

# %%
T={'gh','ty','rt','sd'}
R={'kj','fd','hj','mn'}
R.union(T)
# Out:
# {'fd', 'gh', 'hj', 'kj', 'mn', 'rt', 'sd', 'ty'}

# %%
G={12.3,12.5,12.7,12.9,11.0,11.7}
H={12.1,12.5,13.2,14.3,11.5,15}
G.union(H)
# Out:
# {11.0, 11.5, 11.7, 12.1, 12.3, 12.5, 12.7, 12.9, 13.2, 14.3, 15}

# %%
### Difference
A={2,3,4,4,5,6}
B={2,7,8,9,4,5,}
A.difference(B)
# Out:
# {3, 6}

# %%
A={2,3,4,4,5,6}
B={2,7,8,9,4,5,}
B.difference(A)
# Out:
# {7, 8, 9}

# %%
p={'pooja','geeta','seeta','riya'}
R={'neha','rinku','pooja','divya'}
p.difference(R)
# Out:
# {'geeta', 'riya', 'seeta'}

# %%
p={'pooja','geeta','seeta','riya'}
R={'neha','rinku','pooja','divya'}
R.difference(p)
# Out:
# {'divya', 'neha', 'rinku'}

# %%
A={1,2,3,4,6,7}
B={2,3,4,6,8,9}
R=A.intersection(B)
A.difference(R)
# Out:
# {1, 7}

# %%
o={12,34,56,36,90}
p={23,34,55,98,100}
L=o.intersection(p)
o.difference(L)
# Out:
# {12, 36, 56, 90}

# %%
o={12,34,56,36,90}
p={23,34,55,98,100}
L=p.intersection(o)
p.difference(L)
# Out:
# {23, 55, 98, 100}

# %%
F={12.1,13.5,12.4,17.6}
G={13.6,18.4,13.9,11.6}
J=F.intersection(G)
H=F.union(G)
F.union(G)-F.intersection(G)
# Out:
# {11.6, 12.1, 12.4, 13.5, 13.6, 13.9, 17.6, 18.4}

# %%
S={1,2,3,6,7,8}
R={2,4,10,9,7,5}
C=S.difference(R)
D=R.difference(S)
C.union(D)
# Out:
# {1, 3, 4, 5, 6, 8, 9, 10}

# %%
 ### Add
A={1,2,4,5,8}
B={8,6,9,7,1,3}
A.add(10)
A
# Out:
# {1, 2, 4, 5, 8, 10}

# %%
B.add(12)
B
# Out:
# {1, 3, 6, 7, 8, 9, 12}

# %%
B={8,6,9,7,1,3}
B.add("leela")
B
# Out:
# {1, 3, 6, 7, 8, 9, 'leela'}

# %%
A={1,2,4,5,8}
A.update("geeta")
A
# Out:
# {1, 2, 4, 5, 8, 'a', 'e', 'g', 't'}

# %%
B={8,6,9,7,1,3,"siya"}
B.remove("siya")
B
# Out:
# {1, 3, 6, 7, 8, 9}

# %%
B.discard(3)
B
# Out:
# {1, 6, 7, 8, 9}

# %%
B.remove(7)
B
# Out:
# {1, 6, 8, 9}
